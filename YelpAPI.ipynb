# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install yelpapi
# !pip install tqdm
# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook
# Out:
# Collecting yelpapi
#   Downloading yelpapi-2.5.0-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: requests in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Installing collected packages: yelpapi
# Successfully installed yelpapi-2.5.0
# Requirement already satisfied: tqdm in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\jakec\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %%
# Load API Credentials
with open('/Users/jakec/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#login.items()
#login['api-key']
# Out:
# 'tJG-hrTzDrB4QQPDcCRntUBJDhx7goD5r0whn3jP8x0OeU-lngNYy14Ekeu9X4bBP6JN0EyLDgeuTopQYVycCF6-CpKh7Z94WTB2mdAzJZ1L5txsR3CGo_vUYfmGZHYx'

# %%
yelp=YelpAPI(login['api-key'], timeout_s = 5.0)

# %%
location = 'San Jose, CA 95120'
term = 'taco'

# %%
location.split(',')[0]
# Out:
# 'San Jose'

# %%
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/San Jose-taco.json'

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/San Jose-taco.json already exists.

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 914

# %%
results['region']
# Out:
# {'center': {'longitude': -121.83769226074219, 'latitude': 37.175592612476464}}

# %%
results['businesses']
# Out:
# [{'id': 'CWb2lApN-MvcmzdPp_9jpA',
#   'alias': 'tacos-el-compa-taqueria-san-jose',
#   'name': 'Tacos El Compa Taqueria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gvi9us2uOiBagDp75QrQSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-el-compa-taqueria-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 1017,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.2473719369747,
#    'longitude': -121.885735362849},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1321 Blossom Hill Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1321 Blossom Hill Rd', 'San Jose, CA 95118']},
#   'phone': '+14086228035',
#   'display_phone': '(408) 622-8035',
#   'distance': 9044.620713812314},
#  {'id': 'mm3rmTdhgzBnHPvsFtCGNQ',
#   'alias': 'chispiros-burritos-y-tacos-san-jose',
#   'name': "Chispiro's Burritos Y Tacos",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7PHCsuMXtgeWw3wNVGeMhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chispiros-burritos-y-tacos-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 61,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.22978701079844,
#    'longitude': -121.88469830900429},
#   'transactions': [],
#   'location': {'address1': '6081 Meridian Ave',
#    'address2': 'Ste 20',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95120',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['6081 Meridian Ave', 'Ste 20', 'San Jose, CA 95120']},
#   'phone': '+14084402697',
#   'display_phone': '(408) 440-2697',
#   'distance': 7324.36655141875},
#  {'id': 'Ga9mBeKrJCa2vFMJwUB4YA',
#   'alias': 'taqueria-morgan-grill-morgan-hill',
#   'name': 'Taqueria Morgan Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kQd6ZbanBYmauFI0O_FF1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taqueria-morgan-grill-morgan-hill?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 65,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.1564704371785,
#    'longitude': -121.65190483172017},
#   'transactions': [],
#   'location': {'address1': '1049 Cochrane Rd',
#    'address2': 'Ste 160',
#    'address3': None,
#    'city': 'Morgan Hill',
#    'zip_code': '95037',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1049 Cochrane Rd',
#     'Ste 160',
#     'Morgan Hill, CA 95037']},
#   'phone': '+14086124345',
#   'display_phone': '(408) 612-4345',
#   'distance': 16599.33574247394},
#  {'id': 'pegl1ANL2v862WC8XyTP1w',
#   'alias': 'lucys-mexican-grill-san-jose',
#   'name': "Lucy's Mexican Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hKEW3T_4Q-agHCpPgOPl7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucys-mexican-grill-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 399,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.2510583935572,
#    'longitude': -121.842297801692},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '615 Blossom Hill Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95123',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['615 Blossom Hill Rd', 'San Jose, CA 95123']},
#   'phone': '+14082271430',
#   'display_phone': '(408) 227-1430',
#   'distance': 8401.30781315373},
#  {'id': 'jr5vh63d-gbjn5VevHlWVA',
#   'alias': 'tacos-al-pastor-san-jose-3',
#   'name': 'Tacos Al Pastor',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XynltSMyMpSbN369bR4Ryw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-al-pastor-san-jose-3?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 196,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.2207574, 'longitude': -121.8618559},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '6469 Almaden Expy',
#    'address2': '',
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95120',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['6469 Almaden Expy', 'San Jose, CA 95120']},
#   'phone': '+14089973548',
#   'display_phone': '(408) 997-3548',
#   'distance': 5459.115941534685},
#  {'id': 'kLYvemtE7pxTDCNl3Xmpvg',
#   'alias': 'mexican-cuisine-los-toños-san-jose',
#   'name': 'Mexican Cuisine Los Toños',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zsfu6vCHz8f-1r47oQ4aMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mexican-cuisine-los-to%C3%B1os-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 1,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.30146894406463,
#    'longitude': -121.9515466939219},
#   'transactions': [],
#   'location': {'address1': '1305 S Winchester Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95117',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1305 S Winchester Blvd', 'San Jose, CA 95117']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 17248.04535674555},
#  {'id': 'RJhDdHJWGM86hK5Z2TyKUg',
#   'alias': 'tacos-molina-san-jose',
#   'name': 'Tacos Molina',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kQkhqd4d2-T8wABkUxir8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-molina-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 13,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.24987, 'longitude': -121.87847},
#   'transactions': [],
#   'location': {'address1': '1170 Blossom Hill Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1170 Blossom Hill Rd', 'San Jose, CA 95118']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 9002.020712836877},
#  {'id': 'IhG6xbs_Qacr_2MOESM3eQ',
#   'alias': 'rosario-s-tacos-san-jose',
#   'name': 'Rosario’s Tacos',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XLeEE7Gz0b_gb4ezzG-EsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosario-s-tacos-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 22,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.32078, 'longitude': -121.88395},
#   'transactions': [],
#   'location': {'address1': '889 S Almaden Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['889 S Almaden Ave', 'San Jose, CA 95110']},
#   'phone': '+14083525269',
#   'display_phone': '(408) 352-5269',
#   'distance': 16655.31960630705},
#  {'id': 'YbzuiFDJJqAC0PK2JWgDeg',
#   'alias': 'tacos-el-tucanazo-san-jose',
#   'name': 'Tacos El Tucanazo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HS5mX6KXAbYCC6c0TZ8PfQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-el-tucanazo-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 9,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.2499282543186,
#    'longitude': -121.878830641508},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1170 Blossom Hill Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1170 Blossom Hill Rd', 'San Jose, CA 95118']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 9032.935556410333},
#  {'id': 'bN2kWkTxmXgtOU-kMRkWWA',
#   'alias': 'las-delicias-de-tonita-san-jose',
#   'name': 'Las Delicias De Tonita',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1l-oda4E5j2glmIMHDX58A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/las-delicias-de-tonita-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 175,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.331789710282735,
#    'longitude': -121.88606953159214},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '372 S 3rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95112',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['372 S 3rd St', 'San Jose, CA 95112']},
#   'phone': '+14084175956',
#   'display_phone': '(408) 417-5956',
#   'distance': 17888.297101778247},
#  {'id': 'FI5J97RTWw9vxGtLWvpEGA',
#   'alias': 'los-gallos-taqueria-scotts-valley',
#   'name': 'Los Gallos Taqueria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fbjCRQszzBA7yJfScPTjwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/los-gallos-taqueria-scotts-valley?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 215,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.0614660423396,
#    'longitude': -122.006451915923},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '18 Victor Sq',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'Scotts Valley',
#    'zip_code': '95066',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['18 Victor Sq', 'Ste A', 'Scotts Valley, CA 95066']},
#   'phone': '+18314399803',
#   'display_phone': '(831) 439-9803',
#   'distance': 19619.864371339885},
#  {'id': 'fVGN3trS_Qe58lNtnRL_Jw',
#   'alias': 'tacos-a-la-parrilla-san-jose',
#   'name': 'Tacos A La Parrilla',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rv9lHtXuM4ldzknRoFxlaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-a-la-parrilla-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 412,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.3116332741621,
#    'longitude': -121.810017563403},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2980 Aborn Square Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95121',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2980 Aborn Square Rd', 'San Jose, CA 95121']},
#   'phone': '+14082706220',
#   'display_phone': '(408) 270-6220',
#   'distance': 15324.090313859277},
#  {'id': 'jx7P9vau6W_2oaL25PdalA',
#   'alias': 'la-chilanguita-food-truck-san-jose',
#   'name': 'La Chilanguita Food Truck',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Da2-5U3RO8oPYROm4tkrbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-chilanguita-food-truck-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 10,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.2784393, 'longitude': -121.8350216},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '4144 Monterey Hwy',
#    'address2': None,
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95128',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4144 Monterey Hwy', 'San Jose, CA 95128']},
#   'phone': '+18314980149',
#   'display_phone': '(831) 498-0149',
#   'distance': 11438.461454866863},
#  {'id': 'kG57IE8nqMT2gtKgHePmtA',
#   'alias': 'la-patrona-cocina-mexicana-morgan-hill',
#   'name': 'La Patrona Cocina Mexicana',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DwyyffFLyXisjwc6BmbroA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-patrona-cocina-mexicana-morgan-hill?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 12,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.130676, 'longitude': -121.651901},
#   'transactions': [],
#   'location': {'address1': '17500 Depot St',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Morgan Hill',
#    'zip_code': '95037',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['17500 Depot St', 'Ste 100', 'Morgan Hill, CA 95037']},
#   'phone': '+14086126397',
#   'display_phone': '(408) 612-6397',
#   'distance': 17208.34754575391},
#  {'id': 'YMKoNzCBNyNC141Brt74qg',
#   'alias': 'el-burrito-loco-taco-truck-san-jose',
#   'name': 'El Burrito Loco Taco Truck',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wsB60lbElxfeYfvFIeG8mQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-burrito-loco-taco-truck-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 27,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.2321997154746,
#    'longitude': -121.780491463185},
#   'transactions': [],
#   'location': {'address1': '',
#    'address2': '',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95119',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['San Jose, CA 95119']},
#   'phone': '+14087269527',
#   'display_phone': '(408) 726-9527',
#   'distance': 8079.860404626949},
#  {'id': 'c9qGM2nyFIVEg5OSqP6lIg',
#   'alias': 'la-cueva-mex-grill-saratoga-2',
#   'name': 'La Cueva Mex Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M0gjtLsUHLfOyQSi5cYIXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-cueva-mex-grill-saratoga-2?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 1237,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.2918434, 'longitude': -121.9941259},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '18486 Prospect Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Saratoga',
#    'zip_code': '95070',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['18486 Prospect Rd', 'Saratoga, CA 95070']},
#   'phone': '+14085178603',
#   'display_phone': '(408) 517-8603',
#   'distance': 18927.616342971225},
#  {'id': '8ZhOm7xsUZ8TZ2jo-V7Pug',
#   'alias': 'tacos-chencho-san-jose',
#   'name': 'Tacos Chencho',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YzBfRufk01SMbOCffw_xSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-chencho-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 90,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.3236668, 'longitude': -121.932345},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2211 Stevens Creek Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95128',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2211 Stevens Creek Blvd', 'San Jose, CA 95128']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 18473.97013599016},
#  {'id': 'fAnRjrNVUdvbkP7pwhIRjg',
#   'alias': 'top-tier-tacos-morgan-hill',
#   'name': 'Top Tier Tacos',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A5yidRNn5FFr6WZr6kd7BQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-tier-tacos-morgan-hill?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 21,
#   'categories': [{'alias': 'catering', 'title': 'Caterers'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.12953865, 'longitude': -121.64893294999999},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': '',
#    'city': 'Morgan Hill',
#    'zip_code': '95037',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['Morgan Hill, CA 95037']},
#   'phone': '+14083754067',
#   'display_phone': '(408) 375-4067',
#   'distance': 17495.15756821427},
#  {'id': 'tTrchuQco0l0H_YiIGiPtg',
#   'alias': 'cali-spartan-mexican-kitchen-san-jose-2',
#   'name': 'Cali-Spartan Mexican Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nlxu9qlITe1a2YgT1JSKlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cali-spartan-mexican-kitchen-san-jose-2?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 265,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.24955327197955,
#    'longitude': -121.86921168466361},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1008 Blossom Hill Rd',
#    'address2': 'Ste H',
#    'address3': None,
#    'city': 'San Jose',
#    'zip_code': '95123',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1008 Blossom Hill Rd', 'Ste H', 'San Jose, CA 95123']},
#   'phone': '+14086132983',
#   'display_phone': '(408) 613-2983',
#   'distance': 8684.797060465155},
#  {'id': '7MvsyEl2LOuoTFIJheCAVA',
#   'alias': 'la-carne-asada-san-jose',
#   'name': 'La Carne Asada',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fsw1whnN5t4Smr1nLWpjnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-carne-asada-san-jose?adjust_creative=isf1kTI4iGU7-6jJxanU_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=isf1kTI4iGU7-6jJxanU_A',
#   'review_count': 6,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.335254, 'longitude': -121.8895},
#   'transactions': [],
#   'location': {'address1': '58 S First St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Jose',
#    'zip_code': '95113',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['58 S First St', 'San Jose, CA 95113']},
#   'phone': '+15108378745',
#   'display_phone': '(510) 837-8745',
#   'distance': 18330.281263692832}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                    alias  \
# 0   CWb2lApN-MvcmzdPp_9jpA         tacos-el-compa-taqueria-san-jose
# 1   mm3rmTdhgzBnHPvsFtCGNQ      chispiros-burritos-y-tacos-san-jose
# 2   Ga9mBeKrJCa2vFMJwUB4YA        taqueria-morgan-grill-morgan-hill
# 3   pegl1ANL2v862WC8XyTP1w             lucys-mexican-grill-san-jose
# 4   jr5vh63d-gbjn5VevHlWVA               tacos-al-pastor-san-jose-3
# 5   kLYvemtE7pxTDCNl3Xmpvg       mexican-cuisine-los-toños-san-jose
# 6   RJhDdHJWGM86hK5Z2TyKUg                    tacos-molina-san-jose
# 7   IhG6xbs_Qacr_2MOESM3eQ                 rosario-s-tacos-san-jose
# 8   YbzuiFDJJqAC0PK2JWgDeg               tacos-el-tucanazo-san-jose
# 9   bN2kWkTxmXgtOU-kMRkWWA          las-delicias-de-tonita-san-jose
# 10  FI5J97RTWw9vxGtLWvpEGA        los-gallos-taqueria-scotts-valley
# 11  fVGN3trS_Qe58lNtnRL_Jw             tacos-a-la-parrilla-san-jose
# 12  jx7P9vau6W_2oaL25PdalA       la-chilanguita-food-truck-san-jose
# 13  kG57IE8nqMT2gtKgHePmtA   la-patrona-cocina-mexicana-morgan-hill
# 14  YMKoNzCBNyNC141Brt74qg      el-burrito-loco-taco-truck-san-jose
# 15  c9qGM2nyFIVEg5OSqP6lIg            la-cueva-mex-grill-saratoga-2
# 16  8ZhOm7xsUZ8TZ2jo-V7Pug                   tacos-chencho-san-jose
# 17  fAnRjrNVUdvbkP7pwhIRjg               top-tier-tacos-morgan-hill
# 18  tTrchuQco0l0H_YiIGiPtg  cali-spartan-mexican-kitchen-san-jose-2
# 19  7MvsyEl2LOuoTFIJheCAVA                  la-carne-asada-san-jose
#
#                             name  \
# 0        Tacos El Compa Taqueria
# 1    Chispiro's Burritos Y Tacos
# 2          Taqueria Morgan Grill
# 3           Lucy's Mexican Grill
# 4                Tacos Al Pastor
# 5      Mexican Cuisine Los Toños
# 6                   Tacos Molina
# 7                Rosario’s Tacos
# 8              Tacos El Tucanazo
# 9         Las Delicias De Tonita
# 10           Los Gallos Taqueria
# 11           Tacos A La Parrilla
# 12     La Chilanguita Food Truck
# 13    La Patrona Cocina Mexicana
# 14    El Burrito Loco Taco Truck
# 15            La Cueva Mex Grill
# 16                 Tacos Chencho
# 17                Top Tier Tacos
# 18  Cali-Spartan Mexican Kitchen
# 19                La Carne Asada
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/gvi9us...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/7PHCsu...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/kQd6Zb...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/hKEW3T...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/XynltS...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/zsfu6v...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/kQkhqd...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/XLeEE7...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/HS5mX6...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/1l-oda...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/fbjCRQ...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/Rv9lHt...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/Da2-5U...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/Dwyyff...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/wsB60l...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/M0gjtL...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/YzBfRu...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/A5yidR...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/Nlxu9q...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/fsw1wh...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/tacos-el-compa-taquer...          1017
# 1   https://www.yelp.com/biz/chispiros-burritos-y-...            61
# 2   https://www.yelp.com/biz/taqueria-morgan-grill...            65
# 3   https://www.yelp.com/biz/lucys-mexican-grill-s...           399
# 4   https://www.yelp.com/biz/tacos-al-pastor-san-j...           196
# 5   https://www.yelp.com/biz/mexican-cuisine-los-t...             1
# 6   https://www.yelp.com/biz/tacos-molina-san-jose...            13
# 7   https://www.yelp.com/biz/rosario-s-tacos-san-j...            22
# 8   https://www.yelp.com/biz/tacos-el-tucanazo-san...             9
# 9   https://www.yelp.com/biz/las-delicias-de-tonit...           175
# 10  https://www.yelp.com/biz/los-gallos-taqueria-s...           215
# 11  https://www.yelp.com/biz/tacos-a-la-parrilla-s...           412
# 12  https://www.yelp.com/biz/la-chilanguita-food-t...            10
# 13  https://www.yelp.com/biz/la-patrona-cocina-mex...            12
# 14  https://www.yelp.com/biz/el-burrito-loco-taco-...            27
# 15  https://www.yelp.com/biz/la-cueva-mex-grill-sa...          1237
# 16  https://www.yelp.com/biz/tacos-chencho-san-jos...            90
# 17  https://www.yelp.com/biz/top-tier-tacos-morgan...            21
# 18  https://www.yelp.com/biz/cali-spartan-mexican-...           265
# 19  https://www.yelp.com/biz/la-carne-asada-san-jo...             6
#
#                                            categories  rating  \
# 0          [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 1   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 2          [{'alias': 'mexican', 'title': 'Mexican'}]     5.0
# 3          [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 4   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0
# 5   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     5.0
# 6              [{'alias': 'tacos', 'title': 'Tacos'}]     4.5
# 7              [{'alias': 'tacos', 'title': 'Tacos'}]     5.0
# 8   [{'alias': 'foodtrucks', 'title': 'Food Trucks'}]     5.0
# 9   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 10         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 11         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 12  [{'alias': 'foodtrucks', 'title': 'Food Trucks'}]     5.0
# 13  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     5.0
# 14  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 15  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 16  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 17  [{'alias': 'catering', 'title': 'Caterers'}, {...     5.0
# 18         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 19         [{'alias': 'mexican', 'title': 'Mexican'}]     5.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 37.2473719369747, 'longitude': -1...          [delivery]
# 1   {'latitude': 37.22978701079844, 'longitude': -...                  []
# 2   {'latitude': 37.1564704371785, 'longitude': -1...                  []
# 3   {'latitude': 37.2510583935572, 'longitude': -1...          [delivery]
# 4   {'latitude': 37.2207574, 'longitude': -121.861...          [delivery]
# 5   {'latitude': 37.30146894406463, 'longitude': -...                  []
# 6     {'latitude': 37.24987, 'longitude': -121.87847}                  []
# 7     {'latitude': 37.32078, 'longitude': -121.88395}                  []
# 8   {'latitude': 37.2499282543186, 'longitude': -1...                  []
# 9   {'latitude': 37.331789710282735, 'longitude': ...                  []
# 10  {'latitude': 37.0614660423396, 'longitude': -1...                  []
# 11  {'latitude': 37.3116332741621, 'longitude': -1...  [delivery, pickup]
# 12  {'latitude': 37.2784393, 'longitude': -121.835...  [delivery, pickup]
# 13  {'latitude': 37.130676, 'longitude': -121.651901}                  []
# 14  {'latitude': 37.2321997154746, 'longitude': -1...                  []
# 15  {'latitude': 37.2918434, 'longitude': -121.994...          [delivery]
# 16  {'latitude': 37.3236668, 'longitude': -121.932...                  []
# 17  {'latitude': 37.12953865, 'longitude': -121.64...                  []
# 18  {'latitude': 37.24955327197955, 'longitude': -...                  []
# 19    {'latitude': 37.335254, 'longitude': -121.8895}                  []
#
#    price                                           location         phone  \
# 0     $$  {'address1': '1321 Blossom Hill Rd', 'address2...  +14086228035
# 1    NaN  {'address1': '6081 Meridian Ave', 'address2': ...  +14084402697
# 2    NaN  {'address1': '1049 Cochrane Rd', 'address2': '...  +14086124345
# 3     $$  {'address1': '615 Blossom Hill Rd', 'address2'...  +14082271430
# 4      $  {'address1': '6469 Almaden Expy', 'address2': ...  +14089973548
# 5    NaN  {'address1': '1305 S Winchester Blvd', 'addres...
# 6    NaN  {'address1': '1170 Blossom Hill Rd', 'address2...
# 7    NaN  {'address1': '889 S Almaden Ave', 'address2': ...  +14083525269
# 8      $  {'address1': '1170 Blossom Hill Rd', 'address2...
# 9      $  {'address1': '372 S 3rd St', 'address2': None,...  +14084175956
# 10     $  {'address1': '18 Victor Sq', 'address2': 'Ste ...  +18314399803
# 11    $$  {'address1': '2980 Aborn Square Rd', 'address2...  +14082706220
# 12   NaN  {'address1': '4144 Monterey Hwy', 'address2': ...  +18314980149
# 13   NaN  {'address1': '17500 Depot St', 'address2': 'St...  +14086126397
# 14   NaN  {'address1': '', 'address2': '', 'address3': N...  +14087269527
# 15    $$  {'address1': '18486 Prospect Rd', 'address2': ...  +14085178603
# 16     $  {'address1': '2211 Stevens Creek Blvd', 'addre...
# 17   NaN  {'address1': None, 'address2': None, 'address3...  +14083754067
# 18    $$  {'address1': '1008 Blossom Hill Rd', 'address2...  +14086132983
# 19   NaN  {'address1': '58 S First St', 'address2': None...  +15108378745
#
#      display_phone      distance
# 0   (408) 622-8035   9044.620714
# 1   (408) 440-2697   7324.366551
# 2   (408) 612-4345  16599.335742
# 3   (408) 227-1430   8401.307813
# 4   (408) 997-3548   5459.115942
# 5                   17248.045357
# 6                    9002.020713
# 7   (408) 352-5269  16655.319606
# 8                    9032.935556
# 9   (408) 417-5956  17888.297102
# 10  (831) 439-9803  19619.864371
# 11  (408) 270-6220  15324.090314
# 12  (831) 498-0149  11438.461455
# 13  (408) 612-6397  17208.347546
# 14  (408) 726-9527   8079.860405
# 15  (408) 517-8603  18927.616343
# 16                  18473.970136
# 17  (408) 375-4067  17495.157568
# 18  (408) 613-2983   8684.797060
# 19  (510) 837-8745  18330.281264

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 46

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                alias  \
# 0  mm3rmTdhgzBnHPvsFtCGNQ  chispiros-burritos-y-tacos-san-jose
# 1  Ga9mBeKrJCa2vFMJwUB4YA    taqueria-morgan-grill-morgan-hill
# 2  pegl1ANL2v862WC8XyTP1w         lucys-mexican-grill-san-jose
# 3  jr5vh63d-gbjn5VevHlWVA           tacos-al-pastor-san-jose-3
# 4  kLYvemtE7pxTDCNl3Xmpvg   mexican-cuisine-los-toños-san-jose
#
#                           name  \
# 0  Chispiro's Burritos Y Tacos
# 1        Taqueria Morgan Grill
# 2         Lucy's Mexican Grill
# 3              Tacos Al Pastor
# 4    Mexican Cuisine Los Toños
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/7PHCsu...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/kQd6Zb...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/hKEW3T...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/XynltS...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/zsfu6v...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chispiros-burritos-y-...            61
# 1  https://www.yelp.com/biz/taqueria-morgan-grill...            65
# 2  https://www.yelp.com/biz/lucys-mexican-grill-s...           399
# 3  https://www.yelp.com/biz/tacos-al-pastor-san-j...           196
# 4  https://www.yelp.com/biz/mexican-cuisine-los-t...             1
#
#                                           categories  rating  \
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]     5.0
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 3  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0
# 4  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     5.0
#
#                                          coordinates transactions  \
# 0  {'latitude': 37.22978701079844, 'longitude': -...           []
# 1  {'latitude': 37.1564704371785, 'longitude': -1...           []
# 2  {'latitude': 37.2510583935572, 'longitude': -1...   [delivery]
# 3  {'latitude': 37.2207574, 'longitude': -121.861...   [delivery]
# 4  {'latitude': 37.30146894406463, 'longitude': -...           []
#
#                                             location         phone  \
# 0  {'address1': '6081 Meridian Ave', 'address2': ...  +14084402697
# 1  {'address1': '1049 Cochrane Rd', 'address2': '...  +14086124345
# 2  {'address1': '615 Blossom Hill Rd', 'address2'...  +14082271430
# 3  {'address1': '6469 Almaden Expy', 'address2': ...  +14089973548
# 4  {'address1': '1305 S Winchester Blvd', 'addres...
#
#     display_phone      distance price
# 0  (408) 440-2697   7324.366551   NaN
# 1  (408) 612-4345  16599.335742   NaN
# 2  (408) 227-1430   8401.307813    $$
# 3  (408) 997-3548   5459.115942     $
# 4                  17248.045357   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             913 non-null    object
#  1   alias          913 non-null    object
#  2   name           913 non-null    object
#  3   image_url      913 non-null    object
#  4   is_closed      913 non-null    bool
#  5   url            913 non-null    object
#  6   review_count   913 non-null    int64
#  7   categories     913 non-null    object
#  8   rating         913 non-null    float64
#  9   coordinates    913 non-null    object
#  10  transactions   913 non-null    object
#  11  location       913 non-null    object
#  12  phone          913 non-null    object
#  13  display_phone  913 non-null    object
#  14  distance       913 non-null    float64
#  15  price          763 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 108.0+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/San Jose-taco.csv.gz'

# %%
df.to_csv(csv_file, compression = 'gzip', index = False)
